# %% [markdown]
# ## Standardization

# %%
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
import numpy as np
mean = np.mean(total_bill)
std = np.std(total_bill)

# %%
mean,std
# Out:
# (19.78594262295082, 8.884150577771132)

# %%
sns.histplot(total_bill)
# Out:
# <Axes: ylabel='Count'>

# %%
normalaized_data = []
for i in total_bill:
   z_socre = (i-mean)/std
   normalaized_data.append(z_socre)

print(normalaized_data)
# Out:
# [-0.3147113050904943, -1.0632353132988692, 0.13777989987156145, 0.43831510316725475, 0.540744704290506, 0.6195367051545455, -1.2399545152367863, 0.7985071071171495, -0.5342033074974614, -0.5634689078183903, -1.0711145133852733, 1.7417599174609364, -0.49143050702841123, -0.15262490331304146, -0.557840907756673, 0.2019391005751361, -1.0643609133112126, -0.3935033059545337, -0.31696250511518104, 0.09725829942719795, -0.2100305039425557, 0.05673669898283484, -0.45203450659639155, 2.2100095225958003, 0.003833498402694168, -0.2224121040783337, -0.7221785095588127, -0.7987193103981653, 0.21544630072325727, -0.015301701807144186, -1.1521577142739994, -0.16162970341178864, -0.5319521074727743, 0.10176069947657193, -0.22578890411536368, 0.4810879036363046, -0.3912521059298469, -0.32146490516455467, -0.12335930299211233, 1.2926455125359115, -0.4216433062631192, -0.2618081045103532, -0.6580193088552376, -1.137524914113535, 1.1947183114620337, -0.16838330348584943, 0.2751031013774587, 1.419838313
# ...

# %%
sns.histplot(normalaized_data)
# Out:
# <Axes: ylabel='Count'>

# %%
from sklearn.preprocessing import StandardScaler

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
scaler = StandardScaler()

# %%
scaler
# Out:
# StandardScaler()

# %%
scaler.fit(df[['total_bill','tip']])
# Out:
# StandardScaler()

# %%
import pandas as pd

# %%
pd.DataFrame(scaler.transform(df[['total_bill','tip']]), columns=['total_bill','tips'])
# Out:
#      total_bill      tips
# 0     -0.314711 -1.439947
# 1     -1.063235 -0.969205
# 2      0.137780  0.363356
# 3      0.438315  0.225754
# 4      0.540745  0.443020
# ..          ...       ...
# 239    1.040511  2.115963
# 240    0.832275 -0.722971
# 241    0.324630 -0.722971
# 242   -0.221287 -0.904026
# 243   -0.113229  0.001247
#
# [244 rows x 2 columns]

# %% [markdown]
# ## 2. Normalization (Min , Max scaler) -> 0 to 1

# %%
import seaborn as sns

# %%
df = sns.load_dataset('taxis')

# %%
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
min_max = MinMaxScaler()

# %%
min_max.fit(df[['distance','fare','tip']])
# Out:
# MinMaxScaler()

# %%
min_max.transform(df[['distance','fare','tip']])
# Out:
# array([[0.04359673, 0.04026846, 0.06475904],
#        [0.02152589, 0.02684564, 0.        ],
#        [0.0373297 , 0.04362416, 0.07108434],
#        ...,
#        [0.11280654, 0.10067114, 0.        ],
#        [0.03051771, 0.03355705, 0.        ],
#        [0.10490463, 0.09395973, 0.10120482]])

# %%
min_max.fit_transform(df[['distance','fare','tip']])
# Out:
# array([[0.04359673, 0.04026846, 0.06475904],
#        [0.02152589, 0.02684564, 0.        ],
#        [0.0373297 , 0.04362416, 0.07108434],
#        ...,
#        [0.11280654, 0.10067114, 0.        ],
#        [0.03051771, 0.03355705, 0.        ],
#        [0.10490463, 0.09395973, 0.10120482]])

# %%
min_max.transform([[1,3,4]])
# Out:
# D:\softwares\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# array([[0.02724796, 0.01342282, 0.12048193]])

# %% [markdown]
# ## 3. Unit Vector

# %%
import seaborn as sns

# %%
sns.load_dataset('iris')
df.head()
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# ...

# %%
from sklearn.preprocessing import normalize

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
import pandas as pd
pd.DataFrame(normalize(df[['passengers', 'distance', 'fare', 'tip']]),
             columns=['passengers', 'distance', 'fare', 'tip'])
# Out:
#       passengers  distance      fare       tip
# 0       0.132242  0.211587  0.925692  0.284320
# 1       0.193804  0.153105  0.969020  0.000000
# 2       0.124325  0.170326  0.932440  0.293408
# 3       0.034771  0.267737  0.938818  0.213842
# 4       0.306385  0.220597  0.919154  0.112341
# ...          ...       ...       ...       ...
# 6428    0.208805  0.156604  0.939621  0.221333
# 6429    0.016404  0.307412  0.951435  0.000000
# 6430    0.060397  0.250043  0.966349  0.000000
# 6431    0.161681  0.181083  0.970087  0.000000
# 6432    0.062980  0.242473  0.944701  0.211613
#
# [6433 rows x 4 columns]

# %% [markdown]
# ## 4. PCA (Principal Component Analysis)
